# %% [markdown]
# ## Web Scraping
#
# Web Scraping means gathering useful information from the web.
#
# Here is an example for covid-19 data scraping from worldometers website.

# %%
from selenium import webdriver
import time
import pandas as pd
import os

#path to your chromedriver
chrome_browser = webdriver.Chrome("C:\\Users\\jbhat\\Downloads\\ChromeDriver\\chromedriver.exe")
chrome_browser.get("https://www.worldometers.info/coronavirus/")
time.sleep(15)

column_names=['Rank','Country', 'Total Cases', 'New Cases', 'Deaths', 'New Deaths','Recovered', 'Active Cases', 'Critical']
df=pd.DataFrame(columns= column_names)
print(df)

for i in chrome_browser.find_elements_by_xpath('//*[@id="main_table_countries_today"]/tbody/tr'): # tr for each of country
    td_list=i.find_elements_by_tag_name('td') # tag name retrieve each piece of info for a country
    row=[]
    for td in td_list:
        row.append(td.text) # creating row ie each country data
    data = {}
    for j in range(len(df.columns)):
        data[df.columns[j]] = row[j] 
    df = df.append(data, ignore_index=True)

df = df.iloc[1:]
print(df)

base_path='C:\\Users\\jbhat\\ISB1\\Python Projects\\Covid19 Dataset auto creatror or scraper'

path=os.path.join(base_path,'Covid_Dataset_.csv')
#os.mkdir(path)
df.to_csv(path, index = False)
print("The dataset has been saved at the loction: "+path)
chrome_browser.quit()
# Out:
# Empty DataFrame
# Columns: [Rank, Country, Total Cases, New Cases, Deaths, New Deaths, Recovered, Active Cases, Critical]
# Index: []
#     Rank                 Country Total Cases New Cases   Deaths New Deaths  \
# 1
# 2
# 3      1                     USA   5,796,727            179,200
# 4
# 5      2                  Brazil   3,536,488            113,454
# 6
# 7      3                   India   2,979,562    +6,194   55,950        +22
# 8
# 9      4                  Russia     946,976             16,189
# 10     5            South Africa     603,338             12,843
# 11     6                    Peru     576,067             27,245
# 12     7                  Mexico     549,734    +5,928   59,610       +504
# 13     8                Colombia     522,138             16,568
# 14     9                   Spain     407,879             28,838
# 15    10                   Chile     393,769             10,723
# 16    11                    Iran     354,764             20,376
# 17    12               Argentina     329,043              6,730
# 18    13                      UK     323,313             41,405
# 19    14            Saudi Arabia     305,186              3,580
# 20    15                Pakistan     292,174      +586    6,231        +12
# 21    16              Bangladesh     290,360              3,861
# 22    17                   Italy     257,065             35,427
# 23    18                  Turkey     255,723              6,080
# 24    19                  France     234,400             30,503
# 25    20                 Germany     233,021              9,328
# 26    21                    Iraq     197,085              6,283
# 27    22             Philippines     182,365              2,940
# 28    23               Indonesia     149,408              6,500
# 29    24                  Canada     124,372              9,064
# 30    25                   Qatar     116,481                193
# ..   ...                     ...         ...       ...      ...        ...
# 201  194  St. Vincent Grenadines          58
# 202  195                   Macao          46
# 203  196                 Curaçao          37                  1
# 204  197                    Fiji          28                  1
# 205  198             Saint Lucia          26
# 206  199             Timor-Leste          26
# 207  200                 Grenada          24
# 208  201           New Caledonia          23
# 209  202                    Laos          22
# 210  203  British Virgin Islands          21        +9        1
# 211  204                Dominica          18
# 212  205   Saint Kitts and Nevis          17
# 213  206               St. Barth          16
# 214  207               Greenland          14
# 215  208              Montserrat          13                  1
# 216  209   Caribbean Netherlands          13
# 217  210        Falkland Islands          13
# 218  211            Vatican City          12
# 219  212          Western Sahara          10                  1
# 220  213              MS Zaandam           9                  2
# 221  214   Saint Pierre Miquelon           5
# 222  215                Anguilla           3
# 223
# 224
# 225
# 226
# 227
# 228
# 229
# 230                       Total:  23,125,472   +17,056  803,253       +653
#
#       Recovered Active Cases   Critical
# 1
# 2
# 3     3,127,418    2,490,109     16,801
# 4
# 5     2,670,755      752,279      8,318
# 6
# 7     2,223,202      700,410      8,944
# 8
# 9       761,330      169,457      2,300
# 10      500,102       90,393        539
# 11      384,908      163,914      1,530
# 12      376,409      113,715      3,518
# 13      348,940      156,630      1,493
# 14          N/A          N/A        541
# 15      367,897       15,149      1,072
# 16      305,866       28,522      3,794
# 17      239,806       82,507      1,853
# 18          N/A          N/A         76
# 19      277,067       24,539      1,675
# 20      275,317       10,626        731
# 21      172,615      113,884
# 22      204,960       16,678         69
# 23      235,569       14,074        749
# 24       84,829      119,068        379
# 25      208,950       14,743        236
# 26      140,446       50,356        587
# 27      114,519       64,906        717
# 28      102,991       39,917
# 29      110,648        4,660         62
# 30      113,216        3,072         66
# ..          ...          ...        ...
# 201          56            2
# 202          46            0
# 203          32            4
# 204          20            7
# 205          25            1
# 206          25            1
# 207          24            0
# 208          22            1
# 209          20            2
# 210           8           12
# 211          18            0
# 212          17            0
# 213           9            7
# 214          14            0
# 215          12            0
# 216           7            6
# 217          13            0
# 218          12            0
# 219           8            1
# 220                        7
# 221           1            4
# 222           3            0
# 223
# 224
# 225
# 226
# 227
# 228
# 229
# 230  15,716,611               6,605,608
#
# [230 rows x 9 columns]
# The dataset has been saved at the loction: C:\Users\jbhat\ISB1\Python Projects\Covid19 Dataset auto creatror or scraper\Covid_Dataset_.csv
